# %%
import netCDF4 as nc
import cartopy.crs as ccrs
from datetime import date, timedelta, datetime
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import dask.array as da
import os
import cftime

############ INPUT PATH ##############

rootpath_in = '/bdd/CORDEX/output/'
CORDEX_domain = 'EUR-11'
GCM = 'MOHC-HadGEM2-ES'
scenario = 'rcp45'
RCM = 'KNMI-RACMO22E'
em = 'r1i1p1' #ensemble_member
ver='v2' #version
freq='3hr' #frequency
ver_2='latest'
#version_3=..
#version_4=..
HH_1s='00' #start hour averaged variables (see README.txt)
HH_2s='00' #start hour instantaneous variables 
HH_1e='00' #end hour averaged variables 
HH_2e='21' #end hour instantaneous variables

forcing_in = rootpath_in+CORDEX_domain+'/KNMI/'+GCM+'/'+scenario+'/'+em+'/'+RCM+'/'+ver+'/'+freq 

############################# TIME RANGE DEFINITION ###########

first_year = 2088
last_year = 2100

years=np.arange(first_year, last_year+1, 1) #right value excluded

################################# MASK CALL ######

mask_ocean=xr.open_dataset('/modfs/project/input4CORDEX/output/EUR-11/grid_rotated.nc') #put this file in the shared directory, #modificare il path in modo interattivo
mask=mask_ocean.LANDMASK.data

#################### VARIABLES CALL ##################

for y in years:
    rsds_open= forcing_in+'/rsds/'+ver_2+'/rsds_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_1s+'-'+str(y+1)+'0101'+HH_1e+'.nc'
    rlds_open= forcing_in+'/rlds/'+ver_2+'/rlds_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_1s+'-'+str(y+1)+'0101'+HH_1e+'.nc'
    sfcWind_open= forcing_in+'/sfcWind/'+ver_2+'/sfcWind_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_2s+'-'+str(y)+'1230'+HH_2e+'.nc'
    tas_open= forcing_in+'/tas/'+ver_2+'/tas_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_2s+'-'+str(y)+'1230'+HH_2e+'.nc'
    huss_open= forcing_in+'/huss/'+ver_2+'/huss_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_2s+'-'+str(y)+'1230'+HH_2e+'.nc'
    pr_open= forcing_in+'/pr/'+ver_2+'/pr_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_1s+'-'+str(y+1)+'0101'+HH_1e+'.nc'
    ps_open= forcing_in+'/ps/'+ver_2+'/ps_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_2s+'-'+str(y)+'1230'+HH_2e+'.nc'
    
    shortwave_radiation=xr.open_mfdataset(rsds_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    longwave_radiation=xr.open_mfdataset(rlds_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    surface_wind=xr.open_mfdataset(sfcWind_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    air_temperature=xr.open_mfdataset(tas_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    specific_humidity=xr.open_mfdataset(huss_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    total_precipitation=xr.open_mfdataset(pr_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    surface_pressure=xr.open_mfdataset(ps_open, combine='by_coords', parallel=True,  chunks={'time': 200})
    
    times= shortwave_radiation.time
    rlat = shortwave_radiation.rlat
    rlon = shortwave_radiation.rlon
    lat = shortwave_radiation.lat
    lon = shortwave_radiation.lon

    Fill_value = 9.96921e+36
    SWdown=shortwave_radiation.rename({'rsds': 'SWdown'}).SWdown*mask
    #SWdown_new = da.where(mask == 1, SWdown, Fill_value) #mask filter to keep only land values
    
    LWdown=longwave_radiation.rename({'rlds': 'LWdown'}).LWdown*mask
    #LWdown_new = da.where(mask == 1, LWdown, Fill_value)
    
    Wind=surface_wind.rename({'sfcWind': 'Wind'}).Wind*mask
    #Wind_new = da.where(mask == 1, Wind, Fill_value)
    
    Tair=air_temperature.rename({'tas': 'Tair'}).Tair*mask
    #Tair_new = da.where(mask == 1, Tair, Fill_value)
    
    Qair=specific_humidity.rename({'huss': 'Qair'}).Qair*mask
    #Qair_new = da.where(mask == 1, Qair, Fill_value)

    PSurf = surface_pressure.rename({'ps': 'PSurf'}).PSurf*mask
    #Psurf_new = da.where(mask == 1, Psurf, Fill_value)

    Prec = total_precipitation.rename({'pr': 'Prec'}).Prec*mask

    tstep_data = np.arange(0, len(PSurf.time))
    first_value = 3600 + 1800 # the original files start at 01:30
    time_step = 3*3600 # 3hourly data
    times_data= first_value +((tstep_data) * time_step)
                     
    Rainf = np.zeros((len(PSurf.time), len(Prec.rlat), len(Prec.rlon)))#, chunks=(200, len(rlat), len(rlon)))
    Rainf=np.where(Tair > 273.15, Prec, 0)#*mask
    #Rainf_new = da.where(mask == 1, Rainf, Fill_value)

    Snowf = np.zeros((len(PSurf.time), len(Prec.rlat), len(Prec.rlon)))#, chunks=(200, len(rlat), len(rlon)))  
    Snowf=np.where(Tair <= 273.15, Prec, 0)#*mask
    #Snowf_new = da.where(mask == 1, Snowf, Fill_value)
 

############## OUTPUT PATH #########################################

    
        
    rootpath_out = '/modfs/project/input4CORDEX/output/' #sostituire /scratchx/lrapella con /bdd
    #rootpath_out = '/bdd/E4C/E4C_AgriPV/Forcing4CORDEX/output/' #sostituire /scratchx/lrapella con /bdd

    forcing_out = rootpath_out+CORDEX_domain+'/KNMI/'+GCM+'/'+scenario+'/'+em+'/'+RCM+'/'+ver+'/'+freq+'/forcing_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'.nc'

    if not os.path.isdir(os.path.dirname(forcing_out)):
        os.makedirs(os.path.dirname(forcing_out))

########### CREATION OUTPUT DATASET ################################### 

    ds = nc.Dataset(forcing_out, 'w')

    ds.createDimension('tstep', None)
    ds.createDimension('lat', len(rlat))
    ds.createDimension('lon', len(rlon))

    Lat = ds.createVariable('rlat', 'f4', ('lat', 'lon'))
    Lon = ds.createVariable('rlon', 'f4', ('lat', 'lon'))
    Lat[:]=lat.data#[100:180, 100:255]
    Lon[:]=lon.data#[100:180, 100:255]

    time = ds.createVariable('time', 'f8', ('tstep',))
    time[:] = times_data

    rlatitude = ds.createVariable('latitude','f4', ('lat'))
    rlongitude = ds.createVariable('longitude','f4', ('lon'))
    rlatitude[:] = rlat.data#[100:180]
    rlongitude[:] = rlon.data#[100:255]
    rp = ds.createVariable('rotated_pole', 'i')

    psurf = ds.createVariable('PSurf', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    psurf[:,:,:] = PSurf.data
    tair = ds.createVariable('Tair', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    tair[:,:,:] = Tair.data
    swdown = ds.createVariable('SWdown', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    swdown[:,:,:] = SWdown.data
    lwdown = ds.createVariable('LWdown', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    lwdown[:,:,:] = LWdown.data
    qair = ds.createVariable('Qair', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    qair[:,:,:] = Qair.data
    wind = ds.createVariable('Wind', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    wind[:,:,:] = Wind.data
    snowf = ds.createVariable('Snowf', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    snowf[:,:,:] = Snowf
    rainf = ds.createVariable('Rainf', 'f4', ('tstep', 'lat', 'lon'), fill_value=Fill_value)
    rainf[:,:,:] = Rainf
    contfrac= ds.createVariable('Contfrac', 'f4', ('lat', 'lon'), fill_value=Fill_value)
    contfrac[:,:] = mask#[100:180, 100:255]

    variables_attrs = {
        'time':{'title': 'Time', 'long_name': 'Time axis', 'axis': 'T', 'time_origin': f'{y}-JAN-01 00:00:00', 'units': f'seconds since {y}-01-01 00:00:00',
               'calendar': '360d'}, 
        'latitude': {'standard_name':'latitude', 'long_name' : 'latitude', 'units' : 'degrees_north'},
        'longitude': {'standard_name':'longitude', 'long_name' : 'longitude', 'units' : 'degrees_east'},
        'rlat': {'standard_name':'grid_latitude', 'long_name' : 'latitude in rotated pole grid', 'units' : 'degrees', 'axis': 'Y'},
        'rlon': {'standard_name':'grid_longitude', 'long_name' : 'longitude in rotated pole grid', 'units' : 'degrees', 'axis': 'X'},
        'rotated_pole':{'grid_mapping_name' : 'rotated_latitude_longitude', 'grid_north_pole_latitude': 39.25, 'grid_north_pole_longitude': -162},
        'SWdown': {'units': 'W m-2', 'long_name': 'Surface Downwelling Shortwave Radiation', 'cell_methods': 'time: mean(centre)',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'LWdown': {'units': 'W m-2', 'long_name': 'Surface Downwelling Longwave Radiation', 'cell_methods': 'time: mean(centre)',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Tair':   {'units': 'K', 'long_name': 'Near-surface Air Temperature', 'cell_methods': 'time: instantaneous',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Qair':   {'units': 'kg kg-1', 'long_name': 'Near-surface specific humidity', 'cell_methods': 'time: instantaneous',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Wind':   {'units': 'm s-1', 'long_name': 'Near-surface Wind Speed', 'cell_methods': 'time: instantaneous',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'PSurf':  {'units': 'Pa', 'long_name': 'Surface Air Pressure', 'cell_methods': 'time: instantaneous',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Rainf':  {'units': 'kg m-2 s-1', 'long_name': 'Rainfall Flux', 'cell_methods': 'time: mean(centre)',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Snowf':  {'units': 'kg m-2 s-1', 'long_name': 'Snowfall Flux', 'cell_methods': 'time: mean(centre)',
                  'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'},#, 'missing_value' : 9.96921e+36},
        'Contfrac': {'long_name': 'Land Area Fraction', 'grid_mapping' : 'rotated_pole', 'coordinates' : 'lat lon'}#,'missing_value' : 9.96921e+36}
    }
    
    for var, attrs in variables_attrs.items():
        for attr_name, attr_value in attrs.items():
            ds.variables[var].setncattr(attr_name, attr_value)

    ds.close()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /net/nfs/tools/u20/Python/miniconda3_py311_23.11.0-2/envs/pangeo-meso-2024.01.22/share/proj failed
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 55
#      52 pr_open= forcing_in+'/pr/'+ver_2+'/pr_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_1s+'-'+str(y+1)+'0101'+HH_1e+'.nc'
#      53 ps_open= forcing_in+'/ps/'+ver_2+'/ps_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'0101'+HH_2s+'-'+str(y)+'1230'+HH_2e+'.nc'
# ---> 55 shortwave_radiation=xr.open_mfdataset(rsds_open, combine='by_coords', parallel=True,  chunks={'time': 200})
#      56 longwave_radiation=xr.open_mfdataset(rlds_open, combine='by_coords', parallel=True,  chunks={'time': 200})
#      57 surface_wind=xr.open_mfdataset(sfcWind_open, combine='by_coords', parallel=True,  chunks={'time': 200})
#
# File /net/nfs/tools/u20/Python/miniconda3_py311_23.11.0-2/envs/pangeo-meso-2024.01.22/lib/python3.11/site-packages/xarray/backends/api.py:990, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     987 paths = _find_absolute_paths(paths, engine=engine, **kwargs)
#     989 if not paths:
# --> 990     raise OSError("no files to open")
#     992 if combine == "nested":
#     993     if isinstance(concat_dim, (str, DataArray)) or concat_dim is None:
#
# OSError: no files to open

# %%
import netCDF4 as nc
import numpy as np

rootpath_in = '/bdd/CORDEX/output/'
CORDEX_domain = 'EUR-11'
GCM = 'MOHC-HadGEM2-ES'
scenario = 'rcp45'
RCM = 'KNMI-RACMO22E'
em = 'r1i1p1' #ensemble_member
ver='v2' #version
freq='3hr' #frequency
ver_2='latest'
#version_3=..
#version_4=..
HH_1s='00' #start hour averaged variables (see README.txt)
HH_2s='00' #start hour instantaneous variables 
HH_1e='00' #end hour averaged variables 
HH_2e='21' #end hour instantaneous variables

rootpath_out = '/modfs/project/input4CORDEX/output/' #sostituire /scratchx/lrapella con /bdd
    #rootpath_out = '/bdd/E4C/E4C_AgriPV/Forcing4CORDEX/output/' #sostituire /scratchx/lrapella con /bdd

first_year = 2006
last_year = 2100

years=np.arange(first_year, last_year+1, 1)

for y in years:

    file_path = rootpath_out+CORDEX_domain+'/KNMI/'+GCM+'/'+scenario+'/'+em+'/'+RCM+'/'+ver+'/'+freq+'/forcing_'+CORDEX_domain+'_'+GCM+'_'+scenario+'_'+em+'_'+RCM+'_'+ver+'_'+freq+'_'+str(y)+'.nc'

# Apri il file in modalità append
    with nc.Dataset(file_path, 'a') as ds:
        # Trova la variabile 'time'
        time_var = ds.variables['time']
    
    # Modifica l'attributo 'calendar'
        if 'calendar' in time_var.ncattrs():
            time_var.setncattr('calendar', '360_day')
            print(f"Attributo 'calendar' aggiornato in {file_path}")
        else:
            print("La variabile 'time' non ha l'attributo 'calendar'.")
# Out:
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2006.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2007.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2008.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2009.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2010.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2011.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2012.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2013.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2014.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2015.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2016.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2017.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2018.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2019.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2020.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2021.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2022.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2023.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2024.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2025.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2026.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2027.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2028.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2029.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2030.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2031.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2032.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2033.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2034.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2035.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2036.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2037.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2038.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2039.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2040.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2041.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2042.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2043.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2044.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2045.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2046.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2047.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2048.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2049.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2050.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2051.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2052.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2053.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2054.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2055.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2056.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2057.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2058.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2059.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2060.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2061.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2062.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2063.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2064.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2065.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2066.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2067.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2068.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2069.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2070.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2071.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2072.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2073.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2074.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2075.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2076.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2077.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2078.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2079.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2080.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2081.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2082.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2083.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2084.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2085.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2086.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2087.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2088.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2089.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2090.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2091.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2092.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2093.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2094.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2095.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2096.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2097.nc
# Attributo 'calendar' aggiornato in /modfs/project/input4CORDEX/output/EUR-11/KNMI/MOHC-HadGEM2-ES/rcp45/r1i1p1/KNMI-RACMO22E/v2/3hr/forcing_EUR-11_MOHC-HadGEM2-ES_rcp45_r1i1p1_KNMI-RACMO22E_v2_3hr_2098.nc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 35
#      32 # Apri il file in modalità append
#      33     with nc.Dataset(file_path, 'a') as ds:
#      34         # Trova la variabile 'time'
# ---> 35         time_var = ds.variables['time']
#      37     # Modifica l'attributo 'calendar'
#      38         if 'calendar' in time_var.ncattrs():
#
# KeyError: 'time'

# %%
# Trova l'indice temporale del 30 dicembre
  #  dec_30_index = shortwave_radiation.time.dt.strftime('%m-%d') == '12-30'

#if (y % 4 == 0) and (y % 100 != 0 or y % 400 == 0):
        # Duplicazione dei valori per ciascuna variabile 6 volte
#        PSurf = xr.concat([PSurf] + [PSurf.sel(time=dec_30_index)] * 6, dim='time')
 #       Tair = xr.concat([Tair] + [Tair.sel(time=dec_30_index)] * 6, dim='time')
  #      SWdown = xr.concat([SWdown] + [SWdown.sel(time=dec_30_index)] * 6, dim='time')
   #     LWdown = xr.concat([LWdown] + [LWdown.sel(time=dec_30_index)] * 6, dim='time')
    #    Qair = xr.concat([Qair] + [Qair.sel(time=dec_30_index)] * 6, dim='time')
     #   Wind = xr.concat([Wind] + [Wind.sel(time=dec_30_index)] * 6, dim='time')
      #  Prec = xr.concat([Prec] + [Prec.sel(time=dec_30_index)] * 6, dim='time')
        
        # Riordina i dati temporali dopo aver inserito i nuovi giorni
       # PSurf = PSurf.sortby('time')
        #Tair = Tair.sortby('time')
       # SWdown = SWdown.sortby('time')
       # LWdown = LWdown.sortby('time')
      #  Qair = Qair.sortby('time')
      #  Wind = Wind.sortby('time')
      #  Prec = Prec.sortby('time')
    #else:

        # Duplicazione dei valori per ciascuna variabile 5 volte
     #   PSurf = xr.concat([PSurf] + [PSurf.sel(time=dec_30_index)] * 5, dim='time')
  #      Tair = xr.concat([Tair] + [Tair.sel(time=dec_30_index)] * 5, dim='time')
   #     SWdown = xr.concat([SWdown] + [SWdown.sel(time=dec_30_index)] * 5, dim='time')
    #    LWdown = xr.concat([LWdown] + [LWdown.sel(time=dec_30_index)] * 5, dim='time')
     #   Qair = xr.concat([Qair] + [Qair.sel(time=dec_30_index)] * 5, dim='time')
     #   Wind = xr.concat([Wind] + [Wind.sel(time=dec_30_index)] * 5, dim='time')
      #  Prec = xr.concat([Prec] + [Prec.sel(time=dec_30_index)] * 5, dim='time')
        
        # Riordina i dati temporali dopo aver inserito i nuovi giorni
      #  PSurf = PSurf.sortby('time')
      #  Tair = Tair.sortby('time')
      #  SWdown = SWdown.sortby('time')
   #     LWdown = LWdown.sortby('time')
   #     Qair = Qair.sortby('time')
    #    Wind = Wind.sortby('time')
     #   Prec = Prec.sortby('time')
